# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo1039/2021_PNUAC_AIData/blob/main/07_codelab3_bs_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🏷️ **웹 동작원리**
#
#
# ---
# <img src ='https://drive.google.com/uc?export=view&id=1amZ78fUnfp3o5Q1XVKDG3eAAzKaYlPrp'>
#
# ---

# %% [markdown]
# # Beautiful Soup 모듈
# + HTML 및 XML 문서 를 구문 분석하기 위한 Python 패키지
# + DOM 추출
# + 기본적으로 UTF-8 인코딩 방식이지만 CP949도 지원

# %% [markdown]
# 🏷️ **웹 스크래핑(Web Scraping)과 웹 크롤링(Web Crawling)**
#
#
# ---
# + 웹 스크래핑(Web Scraping) : 웹 사이트 상에서 원하는 정보를 추출하는 기술
# + 웹 크롤링(Web Crawling) : 웹 크롤러(자동화봇)가정해진 규칙에 따라 웹 페이지를 수집해서 각 사이트의 정보를 분류하는 기술
#
#
#
#
# ---

# %% [markdown]
# ## BeautifulSoup 모듈을 활용한 스크래핑

# %% [markdown]
# ### 1. 웹 페이지 가져오기

# %%
#모듈 import 
from urllib.request import urlopen

url = 'https://news.daum.net/ranking/popular'
#웹 페이지 가져오기 
webpage = urlopen(url).read().decode('utf-8')
webpage[:200]
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />'

# %% [markdown]
# ### 2. BeautifulSoup 객체 생성
#
# ```python
# from bs4 import BeautifulSoup as bs
#
# 인스턴스명 = BeautifulSoup(markup, parser)
# ```
# * 첫 번째 인자 : HTML 형식의 문자열
# * 두 번째 인자 : 첫 번째 인자의 문자열을 해석하기 위한 파서
#
#   * **파서(parser) 종류**
#     + html.parser : 파이썬 표준 라이브러리에 포함된 파서로 빠르지만 유연하지 않기 때문에 단순한 HTML문서에 사용
#
#         ```
#         BeautifulSoup(markup, "html.parser")
#         ```
#
#     + lxml : 매우 빠르고 유연하지만 외부 의존
#       - lxml의 HTML 파서
#           ```
#           BeautifulSoup(markup, "lxml")
#           ```
#       - lxml의 XML 파서
#           ```
#           BeautifulSoup(markup, "lxml-xml")
#           ```
#
#     + html5lib : 웹 브라우저와 동일한 방식으로 페이지 구문 분석하는 파서로 매우 느리지만 매우 유연하지만 외부 의존
#         ```
#         BeautifulSoup(markup, "html5lib")
#       ```

# %%
#모듈 import 
from bs4 import BeautifulSoup as bs
#DOM 문서 만들기
html = bs(webpage, 'html.parser')

# %%
type(html)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### 2. **Beautiful Soup 파싱 메소드**
# + 태그명
#   + **.find(태그명)** : 조건에 맞는 태그 1개만 찾음
#   + **.find_all(태그명)** : 조건에 맞는 모든 태그 찾음
# + css선택자
#   + **.select_one(선택자)** : 조건에 맞는 CSS선택자 1개만 찾음
#   + **.select(선택자)** : 조건에 맞는 CSS선택자 찾음

# %% [markdown]
# 🏷️ **HTML과 CSS**
#
#
# ---
#
#
#
# + **HTML(Hyper Text Markup Language)**
#   + 웹페이지 상에서 문단, 제목, 표, 이미지, 동영상 등을 정의하고 웹페이지 내용을 구조화하고 의미를 부여하는 마크업 언어
# + **CSS(Cascading Style Sheet)**
#   + 색상, 레이아웃 및 글꼴등 웹페이지의 디자인 요소를 담당하는 선언형 언어로 스타일 시트(Style Sheet)라고도 하고, HTML로 작성된 웹페이지를 보기 좋게 꾸며주는 스타일 규칙 언어
#
# + 참고 사이트 : <https://www.w3schools.com/>
#
#
# ---

# %% [markdown]
# #mArticle > div.rank_news > ul.list_news2 > li

# %%
#자료 추출하기
lis = html.select('#mArticle > div.rank_news > ul.list_news2 > li')
print(type(lis), ' 요소 수 : ', len(lis))
print(lis[0])
# Out:
# <class 'list'>  요소 수 :  50
# <li data-tiara-layer="news_list" data-tiara-ordnum="1" data-tiara-type="article">
# <div class="rank_num rank_popular">
# <span class="wrap_num">
# <span class="num_rank">
# <span class="num_news num1"></span>
# <span class="screen_out">1</span>
# </span>
# </span>
# </div>
# <a class="link_thumb" href="https://v.daum.net/v/20210709000709976">
# <img alt="암살된 아이티 대통령 시신에 총알 12발..영부인은 고비 넘겨" aria-hidden="true" class="thumb_g" src="https://img1.daumcdn.net/thumb/S95x77ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202107%2F09%2Fyonhap%2F20210709000710061cevj.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="https://v.daum.net/v/20210709000709976">암살된 아이티 대통령 시신에 총알 12발..영부인은 고비 넘겨</a>
# <span class="info_news">연합뉴스</span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                         (멕시코시티=연합뉴스) 고미혜 특파원 = 조브넬 모이즈 아이티 대통령은 피살 당시 모두 12발의 총알을 맞은 것으로 나타났다. 아이티의 카를 앙리 데스탱 판사는 지난 ...
#                     </span>
# </div>
# </div>
# </li>

# %%
#필요한 자료 만들기
for li in lis :
  title = li.select_one('.cont_thumb > .tit_thumb > a').text.replace('"', '')
  info_news = li.select_one('.cont_thumb > .tit_thumb > .info_news').text
  print(title, ":", info_news)
# Out:
# 암살된 아이티 대통령 시신에 총알 12발..영부인은 고비 넘겨 : 연합뉴스
# 치킨 먹고 또 때렸다..직원 12시간 폭행해 숨지게 한 대표, 징역 18년 : 이데일리
# [단독] 김건희 또 다른 논문, 영문 초록 한 문장 뺀 94% 표절 의혹 : 세계일보
# 주말까지 '지금껏 없던' 폭우..끝나면 폭염·열대야 : MBC
# 문 안 열려, 브레이크도.. 운전자 숨진 티볼리 사고[영상] : 국민일보
# 수도권 4단계 되면 6시 이후 2인만 허용..사실상 '야간통금' : 뉴시스
# 정부, 내일 오전 수도권 거리두기 조정안 발표..4단계 격상 예상(종합2보) : 연합뉴스
# '델타 변이' 공포 전 세계 확산..증상엔 두통 · 콧물 감기 : SBS
# '군복 비키니' 여성 NO, 미니스커트 남성 YES..젠더리스 패션은 이제 '숙명' : 머니투데이
# 내일 수도권 거리두기 발표..'오후 6시 통금' 4단계 현실화하나(종합) : 아시아경제
# AZ·얀센 혈전 원인 찾았다..헤파린 부작용 유사하지만 강력 : 중앙일보
# [단독] 이 와중에 친선외교? 유럽 간다며 백신 맞은 의원들 : JTBC
# 정경심 PC 숨겨준 자산관리인..'증거은닉' 유죄 확정 : JTBC
# 백화점발 패닉 직원 화장실 수도꼭지가 감염 통로 가능성 : 중앙일보
# 윤석열 만난 김영환 지식정리돼 있고 지혜로운 분, 걱정없다 : 뉴스1
# 5명 출입 안 된다 거절하자 쇠막대 휘두르고 폭행 : JTBC
# '1천만 원' 짜리 괌 백신 관광 '완판'..없어서 못 판다 : MBC
# 조선시대 궁녀들 어디서 변을 봤을까.. 놀라운 발견 : 국민일보
# [단독] 나도 모르게 내 차 위치 노출..구멍 뚫린 카카오T : SBS
# 어머니에게 아파트 마련해줘라 아버지 유언에도 유산 혼자 차지한 큰형 : 조선일보
# [주진우 라이브] 김건희 단독 인터뷰 매체 발행인 윤석열 가족 검증 이유? 윤 전 총장이 최고 권력 쥐었을 때 벌어질 일 생각하면 아찔해 : KBS
# 9일 수도권 거리두기 발표..'오후 6시 통금' 4단계 유력(종합) : 뉴스1
# [사진톡톡] 대통령의 '진짜' 선물 : 연합뉴스
# [영상] 삼성 역대급 가성비폰? 70만원대 최강 갤S21 유출 : 헤럴드경제
# 은밀하고 아찔한 노출 노하우 : 엘르
# 환경미화원과 몸싸움..벨기에, 주한 대사 즉시 소환한다 : 서울신문
# 차기 대통령 선거 가상대결 이재명 43%·윤석열 33% : YTN
# 두번째 '폭행'에..벨기에 외교장관 대사부부, 돌아오라 : 머니투데이
# 올 하반기 나온다던 국산 코로나 백신, 3大 난제에 막히다 : 조선일보
# 계단·화장실에서 못볼 짓..결국 '동성애자 화장실 출입금지' 내건 종로빌딩 : 머니투데이
# 김영환, 尹에 '입당' 압박 자기 머리로 생각 못하는 정치인 있어(종합) : 뉴시스
# 오후 11시 1243명 확진, 전날보다 45명↑..사상최다 하루 만에 경신할 듯(종합2보) : 뉴스1
# 유은혜, '교육 분야 방역' 긴급브리핑..수도권 4단계 가나(종합) : 뉴스1
# 유명 강사 자질 논란..강의 중단해야 vs 허위 사실 : KBS
# 휴정 때 검사 어깨 두드린 이재용, '억지 합병비율' 파고든 검찰 : 오마이뉴스
# 윤석열 장모 작은어머니 명신이(김건희)가 양 검사 꽉 쥐고 있다 : 오마이뉴스
# 이재명 43% VS 윤석열 33% 격차 더 벌렸다..尹 의혹 제기 '당연한 검증' 62% : 세계일보
# 매우 위험한 가을 올것..미국도 마스크 등 규제 부활하나 : 연합뉴스
# 北 피격 공무원 형 북한 대사관 통해 김정은에 서한 보내 : 뉴스1
# 윤석열-김건희 연결해줬다는 '스님'의 정체는? : 오마이뉴스
# 김건희 해명이 발단된 '논문' 논란..기본도 못 갖춰 : YTN
# 여당 압박에 결국 전국민 재난지원금?.. 재원 마련은 곳곳 '암초' : 한국일보
# 소설가 이외수 의식회복 후 재활..장남 아버지 삶의 의지 보여 : 연합뉴스
# '퇴근 이후 사실상 통금'..4단계 무엇이 달라지나 : 연합뉴스TV
# 해운 세계 1위 50년만에 뒤집힌다..MSC, 머스크 추월 시간문제 : 중앙일보
# 50만원 예상했는데 1800만원..'납작복숭아' 36배 대박 : 한국경제
# [르포] 2030 영끌해도 못 사..대출규제 풀자 중저가 아파트값↑ : JTBC
# 도쿄올림픽 무관중 개최 결정.. 125년 올림픽 사상 처음 : 조선일보
# [윤희영의 News English] 이 더위에 미지근한 물로 샤워 하라는 이유 : 조선일보
# 수도권 다음주부터 '4단계'..오후 6시 이후 사실상 '통금' : 한국경제

# %% [markdown]
# ## 해결문제
# ---
# 댓글많은 뉴스를 사이트의 제목을 수집해서 AI Cloud의 무료 AI 서비스 중 텍스트 감정 분석 결과를 분석하고 결과를 파일로 저장하시오.단, 감성분석 분석(긍정,중립,부정)은 함수를 이용하여 작성하고 댓글수와 제목의 쉼표는 제거하시오.
#
# 예시)
# news.csv 내용
# ```
# 순위,제목,댓글수,언론사,감성,신뢰도
# 1,故손정민 父 "서울경찰청 정민이와 나를 미워한다",2564,데일리안,부정,0.9970703125
# 2,신고만하면 한국인? "中에 나라 파냐" 국적법 때린 반중정서,2274,중앙일보,부정,0.99755859375
# 3,'잔여 백신' 첫날 젊은층 대거 몰렸다..AZ 부정적 시선 바뀌나,1726,파이낸셜뉴스,부정,0.98974609375
# 4,'도쿄올림픽 지도서 독도 삭제' 요구에 日정부 "수용 불가",1543,연합뉴스,부정,0.9873046875
#
# ...
#
# 47,"손정민 사건 제가 책임지고"..경찰 '김창룡 청장 가짜뉴스' 내사,115,뉴스1,부정,0.9921875
# 48,로또 1등 수령자에 통장 비번 요구·5억 적금 강매한 농협,105,뉴스1,부정,0.99072265625
# 49,'도쿄올림픽 지도서 독도 삭제' 韓요구에 日정부 "수용 불가",97,중앙일보,부정,0.986328125
# 50,올림픽 취소로 日 배상금 떠안나..日언론 "IOC와 불평등 계약",93,뉴스1,부정,0.99609375
#
# ```

# %% [markdown]
# https://news.daum.net/ranking/bestreply

# %%
from urllib.request import urlopen
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs
import json

# %%
def getPage(url) :
  webpage = urlopen(url).read().decode('utf-8')
  return webpage

# %%
def AiCloud(msg) :
  url = "http://svc.saltlux.ai:31781"
  headers={"Content-Type":"application/json" } 

  apiKey = "8faf8aa0-68e2-458b-a57e-c8ab31248751"
  rqData = {
     "key": apiKey,
     "serviceId": "11987300804",
     "argument": {
         "type": "0",
         "query": msg
     }
  }
  # 요청 객체 생성
  req = Request(url, headers=headers)

  # 전달 데이터 json 형태로 만들기
  jdata = json.dumps(rqData).encode('utf-8')

  #요청
  response = urlopen(req, jdata)

  # 요청에 대한 응답처리
  resp = response.read().decode('utf-8')
  resp = json.loads(resp)
  label = resp['label']
  score = resp['score']

  #응답처리 반환
  return label, score

# %%
url = 'https://news.daum.net/ranking/bestreply'

wp = getPage(url)
wp
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />\n<meta property="og:site_name" content="다음뉴스" />\n<meta property="og:title" content="뉴스 랭킹"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="다음뉴스" />\n<meta property="og:url" content="https://news.daum.net/ranking/bestreply" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>뉴스 랭킹 | 다음뉴스</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5dbfb0e/common.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5dbfb0e/news.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5dbfb0e/calendar.css.merged.css" />\n\n<!--[if lte IE 8]>\n<script src="https://m2.daumcdn.net/svc/original/U0301/cssjs/JSON-js/fc535e9cc8/json2.min.js"></script>\n<![endif]-->\n<!--[if lt IE 9]>\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5dbfb0e/ie8.css.merged.css" />\n<![endif]-->\n\n<script src="//t1.daumcdn.net/media/kraken/news/5dbfb0e/common.merged.js"></script>\n\n<script type="text/javascript" src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js"></script>\n\n<script>\n  var ENV = {\n    Profile: {\n      isProduction: \'true\' || false,\n      isSandbox: \'\' || false,\n      isCbt: \'\' || false,\n    }\n  }\n</script>\n        <script src="//t1.daumcdn.net/media/kraken/news/5dbfb0e/rankingMain.merged.js"></script>\n</head>\n<body class="bg_news">\n<div id="kakaoIndex">\n    <a href="#kakaoBody">본문 바로가기</a>\n    <a href="#kakaoGnb">메뉴 바로가기</a>\n</div>\n\n<div id="kakaoWrap" class="news_type1">\n<div id="wrapMinidaum"></div>\n<script type="text/javascript">\n\tvar minidaum_options = {\n\t\tbgType\t\t\t\t: "white",\n\t\tenableLogoutRetun\t: true,\n\t\tdisableTracker\t\t: true, // false일 경우 사용, true일 경우 미사용\n\t\tenableShield\t\t: false\n\t};\n</script>\n<script src="https://go.daum.net/minidaum_pc.daum"></script>\n\n<div id="kakaoHead" role="banner">\n\t<div class="head_media">\n\t\t<h1>\n\t\t\t<a href="https://news.daum.net/" id="kakaoServiceLogo" data-tiara-layer="GNB default service_news"><span class="ir_wa">뉴스</span></a>\n\t\t</h1>\n\t\t<strong class="screen_out">관련서비스</strong>\n\t\t<ul id="kakaoRelServices" data-tiara-layer="GNB default">\n\t\t\t<li><a href="https://entertain.daum.net" class="link_services link_services1" data-tiara-layer="service_enter"><span class="ir_wa">연예</span></a></li>\n\t\t\t<li><a href="https://sports.daum.net" class="link_services link_services2" data-tiara-layer="service_sports"><span class="ir_wa">스포츠</span></a></li>\n\t\t</ul>\n<h2 class="screen_out">검색</h2>\n<div class="search_news" id="search_news">\n\t<form id="kakaoSearch" name="kakaoSearch" action="//search.daum.net/search" method="get">\n\t\t<fieldset class="fld_inside">\n\t\t\t<legend class="screen_out">검색어 입력폼</legend>\n\t\t\t<div class="box_searchbar">\n\t\t\t\t<label for="qVal" class="lab_search">통합검색</label>\n\t\t\t\t<input type="hidden" name="DA" value="23A" />\n\t\t\t\t<input type="hidden" name="rtmaxcoll" value="NNS">\n\t\t\t\t<input type="text" class="tf_keyword" id="qVal" name="q" value="" title="검색어 입력" autocomplete="off" spellcheck="false">\n\t\t\t\t<button id="kakaoBtnSearch" class="btn_search" type="submit"><span class="ir_wa">검색</span></button>\n\t\t\t</div>\n\t\t</fieldset>\n\t\t<div id="wrap_suggestBox" class="wrap_suggestBox">\n\t\t\t<div id="suggestBox" class="suggestBox box_sub">\n\t\t\t\t<div class="baseBox bg" style="display: none"></div>\n\t\t\t</div>\n\t\t</div>\n\t</form>\n</div>\n<script type="text/javascript" src="https://search1.daumcdn.net/search/suggest_pc/ ...

# %%
html = bs(wp, 'html.parser')

# %%
lis = html.select('#mArticle > div.rank_news > ul.list_news2 > li')
lis[0]
# Out:
# <li data-tiara-layer="news_list" data-tiara-ordnum="1" data-tiara-type="article">
# <div class="rank_num ">
# <span class="wrap_num">
# <span class="num_rank">
# <span class="num_news num1"></span>
# <span class="screen_out">1</span>
# </span>
# </span>
# <span class="info_rank">
# <span class="screen_out">댓글수</span>
# <span class="ico_news2">3,559</span>
# </span>
# </div>
# <a class="link_thumb" href="https://news.v.daum.net/v/20210708221442881">
# <img alt="[단독] 김건희 또 다른 논문, 영문 초록 한 문장 뺀 94% 표절 의혹" aria-hidden="true" class="thumb_g" src="https://img1.daumcdn.net/thumb/S95x77ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202107%2F08%2Fsegye%2F20210708221442366bszl.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="https://news.v.daum.net/v/20210708221442881">[단독] 김건희 또 다른 논문, 영문 초록 한 문장 뺀 94% 표절 의혹</a>
# <span class="info_news">세계일보</span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                         윤석열 전 검찰총장 부인 김건희씨. 연합뉴스  야권 유력 대선주자인 윤석열 전 검찰총장 부인 김건희씨의 박사학위 논문 표절 의혹에 대해 국민대가 검증에 들어간 가...
#                     </span>
# </div>
# </div>
# </li>

# %%
lis[0].select_one('.screen_out').text
# Out:
# '1'

# %%
lis[0].select_one('.ico_news2').text.replace(',','')
# Out:
# '3559'

# %%
lis[0].select_one('.tit_thumb > a').text
# Out:
# '[단독] 김건희 또 다른 논문, 영문 초록 한 문장 뺀 94% 표절 의혹'

# %%
lis[0].select_one('.info_news').text
# Out:
# '세계일보'

# %%
with open('/content/drive/MyDrive/2021_PNUAC_AIData-main/data/news.csv', 'w') as fp :
  linehead = '순위,제목,댓글수,언론사,감성,신뢰도\n'
  fp.write(linehead)
  for li in lis :
    rank = li.select_one('.screen_out').text
    title = li.select_one('.tit_thumb > a').text.replace(',','')
    cnt = li.select_one('.ico_news2').text.replace(',','')
    news = li.select_one('.info_news').text
    aicloud = AiCloud(title)
    #aicloud = ['부정', '0.9']
    line = f'{rank},{title},{cnt},{news},{aicloud[0]},{aicloud[1]}\n'

    print(line)
    fp.write(line)
# Out:
# 1,[단독] 김건희 또 다른 논문 영문 초록 한 문장 뺀 94% 표절 의혹,3559,세계일보,부정,0.96728515625
#
# 2,윤석열 장모 작은어머니 "명신이(김건희)가 양 검사 꽉 쥐고 있다",3542,오마이뉴스,부정,0.912109375
#
# 3,윤석열 만난 김영환 "지식정리돼 있고 지혜로운 분 걱정없다",3123,뉴스1,긍정,0.99072265625
#
# 4,윤석열-김건희 연결해줬다는 '스님'의 정체는?,2566,오마이뉴스,중립,0.70751953125
#
# 5,정경심 PC 숨겨준 자산관리인..'증거은닉' 유죄 확정,2454,JTBC,부정,0.99609375
#
# 6,계단·화장실에서 못볼 짓..결국 '동성애자 화장실 출입금지' 내건 종로빌딩,2154,머니투데이,부정,0.9951171875
#
# 7,'윤석열 부인' 논문.."표절률 43% 기사·블로그 짜깁기",2012,MBC,부정,0.99462890625
#
# 8,김건희 해명이 발단된 '논문' 논란.."기본도 못 갖춰",1790,YTN,부정,0.99658203125
#
# 9,[타임라인]취임 석 달만에 대유행..오세훈 방역 시험대,1575,노컷뉴스,부정,0.5712890625
#
# 10,[단독] 이 와중에 친선외교? 유럽 간다며 백신 맞은 의원들,1460,JTBC,부정,0.99462890625
#
# 11,'아바타를 개발을 중심으로' '회원 Yuji'.. 尹 아내 논문논란 일파만파,1365,쿠키뉴스,부정,0.9853515625
#
# 12,수도권 4단계 되면 6시 이후 2인만 허용..사실상 '야간통금',1100,뉴시스,부정,0.96337890625
#
# 13,"문 안 열려 브레이크도.." 운전자 숨진 티볼리 사고[영상],1023,국민일보,부정,0.97705078125
#
# 14,두번째 '폭행'에..벨기에 외교장관 "대사부부 돌아오라",839,머니투데이,부정,0.98974609375
#
# 15,김영환 尹에 '입당' 압박 "자기 머리로 생각 못하는 정치인 있어"(종합),775,뉴시스,부정,0.99560546875
#
# 16,정부 내일 오전 수도권 거리두기 조정안 발표..4단계 격상 예상(종합2보),753,연합뉴스,중립,0.73828125
#
# 17,'member Yuji' 김건희 논문..여당 "尹 조국처럼 조사해라",753,머니투데이,부정,0.97021484375
#
# 18,차기 대통령 선거 가상대결 이재명 43%·윤석열 33%,739,YTN,중립,0.70947265625
#
# 19,내일 수도권 거리두기 발표..'오후 6시 통금' 4단계 현실화하나(종합),724,아시아경제,부정,0.88525390625
#
# 20,[주진우 라이브] 김건희 단독 인터뷰 매체 발행인 "윤석열 가족 검증 이유? 윤 전 총장이 최고 권력 쥐었을 때 벌어질 일 생각하면 아찔해",633,KBS,부정,0.98681640625
#
# 21,이준석 일본대사에 "일본 정당과 교류 가속화할 것",597,뉴시스,중립,0.59716796875
#
# 22,9일 수도권 거리두기 발표..'오후 6시 통금' 4단계 유력(종합),582,뉴스1,중립,0.630859375
#
# 23,日스가 문대통령 방일하면 "외교상 정중히 대응하는 게 당연",496,연합뉴스,부정,0.75927734375
#
# 24,"치킨 먹고 또 때렸다"..직원 12시간 폭행해 숨지게 한 대표 징역 18년,467,이데일리,부정,0.99609375
#
# 25,여당 압박에 결국 전국민 재난지원금?.. 재원 마련은 곳곳 '암초',437,한국일보,부정,0.99658203125
#
# 26,'군복 비키니' 여성 NO 미니스커트 남성 YES"..젠더리스 패션은 이제 '숙명',429,머니투데이,부정,0.380615234375
#
# 27,"프로라면 이랬을텐데".. '초보 정치인' 윤석열과 최재형[청계천 옆 사진관],429,동아일보,부정,0.88916015625
#
# 28,이재명 43% VS 윤석열 33% 격차 더 벌렸다..尹 의혹 제기 '당연한 검증' 62%,372,세계일보,부정,0.97216796875
#
# 29,유은혜 '교육 분야 방역' 긴급브리핑..수도권 4단계 가나(종합),371,뉴스1,중립,0.9150390625
#
# 30,"5명 출입 안 된다" 거절하자 쇠막대 휘두르고 폭행,318,JTBC,부정,0.9970703125
#
# 31,주말까지 '지금껏 없던' 폭우..끝나면 폭염·열대야,303,MBC,부정,0.982421875
#
# 32,AZ·얀센 혈전 원인 찾았다..헤파린 부작용 유사하지만 강력,296,중앙일보,긍정,0.7666015625
#
# 33,"환경미화원과 몸싸움"..벨기에 주한 대사 즉시 소환한다,276,서울신문,부정,0.99365234375
#
# 34,北 피격 공무원 형 "북한 대사관 통해 김정은에 서한 보내",273,뉴스1,부정,0.994140625
#
# 35,"방역실패가 우리탓?..동네북인가" 분통터지는 2030,267,매일경제,부정,0.998046875
#
# 36,[영상] "삼성 역대급 가성비폰?" 70만원대 최강 갤S21 유출,265,헤럴드경제,긍정,0.97021484375
#
# 37,"야외집회라 확진자 안나왔다" 방역지침 훈수까지 둔 민노총,254,중앙일보,부정,0.9921875
#
# 38,이낙연 "바닥이 꿈틀거린다"..여권 대선주자 지지율 19.4%로 2위,252,중앙일보,부정,0.97998046875
#
# 39,암살된 아이티 대통령 시신에 총알 12발..영부인은 고비 넘겨,249,연합뉴스,부정,0.994140625
#
# 40,"방역수칙 지키면 되지 않나"..저녁 되자 2030 북적,238,JTBC,부정,0.9833984375
#
# 41,"사실상 봉쇄..내일 발표" 수도권 거리두기 4단계 뭐가 달라지나?,229,서울신문,부정,0.9892578125
#
# 42,김건희 해명이 발단된 '논문' 논란.."기본도 못 갖춰",227,YTN,부정,0.99658203125
#
# 43,'델타 변이' 공포 전 세계 확산..증상엔 두통 · 콧물 감기,209,SBS,부정,0.96923828125
#
# 44,[르포] 2030 "영끌해도 못 사"..대출규제 풀자 중저가 아파트값↑,209,JTBC,부정,0.9931640625
#
# 45,오후 11시 1243명 확진 전날보다 45명↑..사상최다 하루 만에 경신할 듯(종합2보),161,뉴스1,긍정,0.642578125
#
# 46,서울시 '광화문 광장 세월호 기억공간' 26일까지 철거 통보,160,경향신문,부정,0.97802734375
#
# 47,최저임금 노사 간극 '2080→1700원'..민주노총 집단 퇴장(종합),152,아시아경제,부정,0.9892578125
#
# 48,스가 "문 대통령 도쿄올림픽 오면 정중히 대응할 것",148,중앙일보,중립,0.52001953125
#
# 49,올 하반기 나온다던 국산 코로나 백신 3大 난제에 막히다,122,조선일보,부정,0.79541015625
#
# 50,도쿄올림픽 무관중 개최 결정.. 125년 올림픽 사상 처음,103,조선일보,중립,0.7099609375

# %% [markdown]
# ---
#
#
# ※ 카카오톡 메신저 내용 분석해보기
#
#
# ---
